# %%
import numpy as np
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
# initialize dlib's face detector
detector = dlib.get_frontal_face_detector()
# and then create the facial landmark predictor
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
img = cv2.imread('Pictures/anger.jpg') #use flag=0 to read as gray
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
#detect face in the image using detector
faces = detector(img)

# %%
for face in faces:
    landmarks = predictor(img, face)
    
    for n in range(0,68):
        #x and y of each point
        x = landmarks.part(n).x
        y = landmarks.part(n).y
        cv2.circle(img, (x,y), 4, (0,0,0), -1)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img = cv2.imread('Pictures/smile.jpg', 0) #use flag=0 to read as gray
plt.imshow(img, cmap='gray')
plt.show()

# %%
faces = detector(img)
for face in faces:
    landmarks = predictor(img, face)
    
    for n in range(0,68):
        #x and y of each point
        x = landmarks.part(n).x
        y = landmarks.part(n).y
        cv2.circle(img, (x,y), 4, (0,0,0), -1)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
